# %%
import pandas as pd
import numpy as np
import csv
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Cargando Datos...**

# %%
df=pd.read_csv('regLin.csv')
df.head()
# Out:
#            X          y
# 0  35.657897  28.074403
# 1  48.685931  36.674434
# 2  95.861773  67.903577
# 3  25.997253  11.931727
# 4  49.964772  30.286144

# %% [markdown]
# **Data Partition con 75% de datos para entrenar**

# %%
X_train,X_test,y_train,y_test=train_test_split(df[['X']],df[['y']],test_size=.25)

# %% [markdown]
# **Ajustando una regresión Train**

# %%
plt.scatter(X_train,y_train)

# %%
linReg=LinearRegression()
linReg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
w0=linReg.intercept_[0]
w1=linReg.coef_[0][0]
print(w0,w1)
# Out:
# 2.69860081188 0.605324819283

# %% [markdown]
# **Test model: Error cuadratico medio**

# %%
ECM=np.mean((linReg.predict(X_test)-y_test)**2)
print(ECM)
# Out:
# y    17.119536
# dtype: float64

# %% [markdown]
# **GRAFICANDO DATOS Y RESULTADO**

# %%
x = np.linspace(float(X_test.min()),float(X_test.max()),500) # 100 numeros espaciados
plt.plot(x,x*w1+w0,color='red')
plt.scatter(X_test,y_test,alpha=0.6)

# %% [markdown]
# ### Haga un gráfico de como cambia el error al cambiar las w´s. Haga uno para w0 y uno para w1. Ponga un punto rojo para los valores encontrados por la regresión lineal

# %%
W0=np.linspace(w0-1.5,w0+1.5,100)
err=[np.mean((i+w1*X_train-np.array(y_train))**2) for i in W0]
plt.scatter(W0,err)
plt.plot(w0,np.mean((w0+w1*X_train-np.array(y_train))**2),'p-',color='red',ms=9)

# %% [markdown]
# **Para w1...**

# %%
W1=np.linspace(w1-1,w1+1,100)
err=[np.mean((w0+i*X_train-np.array(y_train))**2) for i in W1]
plt.scatter(W1,err)
plt.plot(w1,np.mean((w0+w1*X_train-np.array(y_train))**2),'p-',color='red',ms=9)

# %% [markdown]
# # Reglin2

# %%
df2=pd.read_csv('regLin2.csv')
df2.head()
# Out:
#            X            y
# 0  99.320698  5939.441068
# 1  40.493010  1110.673401
# 2  55.350489  2346.004414
# 3  63.938261  2672.828947
# 4  54.209839  1371.676095

# %%
X_train,X_test,y_train,y_test=train_test_split(df2[['X']],df2[['y']],test_size=.25)

# %%
plt.scatter(X_train,y_train)

# %%
linReg2=LinearRegression()
linReg2.fit(X_train**2,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
w0=linReg2.intercept_[0]
w1=linReg2.coef_[0][0]
print(w0,w1)
# Out:
# 23.3529924151 0.610506642775

# %%
ECM=np.mean((linReg2.predict(X_test**2)-y_test)**2)
print(ECM)
# Out:
# y    75878.026942
# dtype: float64

# %%
x = np.linspace(float(X_test.min()),float(X_test.max()),100) # 100 numeros espaciados
plt.plot(x,(x**2)*w1+w0,color='red',ms=19)
plt.scatter(X_test,y_test,alpha=0.6)

# %%
W0=np.linspace(w0-50,w0+50,100)
err=[np.mean((i+w1*X_train**2-np.array(y_train))**2) for i in W0]
plt.scatter(W0,err)
plt.plot(w0,np.mean((w0+w1*X_train**2-np.array(y_train))**2),'p-',color='red',ms=9)

# %%
W1=np.linspace(w1-1,w1+1,100)
err=[np.mean((w0+i*X_train**2-np.array(y_train))**2) for i in W1]
plt.scatter(W1,err)
plt.plot(w1,np.mean((w0+w1*X_train**2-np.array(y_train))**2),'p-',color='red',ms=9)

# %% [markdown]
# # RegLin3

# %%
df3=pd.read_csv('regLin3.csv')
df3.head()
# Out:
#            X         y
# 0  63.104562  0.269342
# 1  31.338077 -0.077771
# 2  65.006731  0.823024
# 3  84.467298  0.348250
# 4  49.336664 -0.800913

# %%
X_train,X_test,y_train,y_test=train_test_split(df3[['X']],df3[['y']],test_size=.25)

# %%
plt.scatter(X_train,y_train)

# %%
linReg3=LinearRegression()
linReg3.fit(np.sin(X_train),y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
w0=linReg3.intercept_[0]
w1=linReg3.coef_[0][0]
print(w0,w1)
# Out:
# 3.76547126812e-11 1.00000000002

# %%
ECM=np.mean((linReg3.predict(np.sin(X_test))-y_test)**2)
print(ECM)
# Out:
# y    3.763440e-18
# dtype: float64

# %%
x = np.linspace(float(X_test.min()),float(X_test.max()),100) # 100 numeros espaciados
plt.plot(x,np.sin(x)*w1+w0,color='red')
plt.scatter(X_test,y_test,alpha=0.6)

# %%
W0=np.linspace(w0-1,w0+1,100)
err=[np.mean((i+w1*np.sin(X_train)-np.array(y_train))**2) for i in W0]
plt.scatter(W0,err)
plt.plot(w0,np.mean((w0+w1*np.sin(X_train)-np.array(y_train))**2),'p-',color='red',ms=9)

# %%
W1=np.linspace(w1-1,w1+1,100)
err=[np.mean((w0+i*np.sin(X_train)-np.array(y_train))**2) for i in W1]
plt.scatter(W1,err)
plt.plot(w1,np.mean((w0+w1*np.sin(X_train)-np.array(y_train))**2),'p-',color='red',ms=9)

# %% [markdown]
# # Reglin4

# %%
df4=pd.read_csv('regLin4.csv')
df4.head()
# Out:
#            X  y
# 0  71.130300  0
# 1  36.872465  0
# 2  56.508402  0
# 3  78.120147  0
# 4  65.575073  0

# %%
X_train,X_test,y_train,y_test=train_test_split(df4[['X']],df4[['y']],test_size=.25)

# %%
plt.scatter(X_train,y_train)

# %%
linReg4=LinearRegression()
linReg4.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
w0=linReg4.intercept_[0]
w1=linReg4.coef_[0][0]
print(w0,w1)
# Out:
# 0.951403789233 -0.0128697061757

# %%
ECM=np.mean((linReg4.predict(X_test)-y_test)**2)
print(ECM)
# Out:
# y    0.077339
# dtype: float64

# %%
x = np.linspace(float(X_test.min()),float(X_test.max()),100) # 100 numeros espaciados
plt.plot(x,1.0/(1+np.exp(-(x*w1+w0))),color='red')
plt.scatter(X_test,y_test,alpha=0.6)
